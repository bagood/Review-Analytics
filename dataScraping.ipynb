# %%
from dataCollection.main import get_restaurant_reviews

# %%
restaurant_name = 'pizza e birra'
all_reviews = get_restaurant_reviews('pizza e birra')

# %%
all_reviews
# Out:
#                                     restaurant_review restaurant_name  \
# 0   Kesini waktu weekend dan kebetulan Timnas lagi...   pizza e birra
# 1   tempat pizza dan pasta terfavorit di Bandung. ...   pizza e birra
# 2   Berhubung Bandung sedang sering-seringnya huja...   pizza e birra
# 3   Diajak teman makan disini terus tau2 terjebak ...   pizza e birra
# 4   Nuker poin 200 buat butter rice ga worth it si...   pizza e birra
# 5   One of my fav places to eat pasta and/or pizza...   pizza e birra
# 6   tiap ke sini aku pasti beli pasta nya karena r...   pizza e birra
# 7   Somehow merasa udangnya terlalu sedikit dan po...   pizza e birra
# 8   Jujur kalau di Bandung pengen nge-beer, entah ...   pizza e birra
# 9   asli ciken wing nya enak bgt kerasa bgt di lid...   pizza e birra
# 10  Pizza e birra ini emang paling cocok sih buat ...   pizza e birra
# 11  Butuh tempat nongkrong sembari nonton pertandi...   pizza e birra
# ...
